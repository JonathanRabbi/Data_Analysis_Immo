# %% [markdown]
# <h1> Analysis of The Visualisation </h1>

# %% [markdown]
# <h2>Correlation Matrix</h2>
#
# The correlation matrix conveys how strong the relationship is between the variables

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h2> Scatter Plot: Construction Year vs Price</h2>
#
# The below scatter plot conveys the relationship of whether there is a trend between newer buildings and their price.
# Moreover, the color coding presents the energy class of the buildings.
#
# We can see that the newer buildings being constructed are of higher EPC value.
#
# EPC = how sustainable the building is

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h2> Heating Types</h2>
#
# The below bar chart displays the majority of buildings are being heated by Gas, followed by Fuel. Additionally, it can be seen that Solar is used the least (1 data point)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <h2> Distribution of Properties in Belgian provinces + Luxembourg</h2>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Prices per Province**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Heating and energy class**

# %% [markdown]
# ![image.png](attachment:image.png)
